# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class CircularLL:
    def __init__(self):
        self.head=None
        self.tail=None
        
    def __iter__(self):
        node= self.head
        while node:
            yield node
            node= node.next
            
            if node==self.tail.next:
                break
                
        
    def createCLL(self,val):
        node = Node(val)
        node.next = node
        self.head=node
        self.tail=node
        return "The CLL has been created"
    
    def insertCLL(self,val,location):
        if self.head==None:
            return "Node not found"
        else:
            newNode = Node(val)
            if location==0:
                newNode.next = self.head
                self.head = newNode
                self.tail.next = newNode
                
                
                
            elif location==-1:
                newNode.next=self.tail.next
                self.tail.next = newNode
                self.tail=newNode  
            
            else:
                tempnode= self.head
                index=0
                while index<location-1:
                    tempnode= tempnode.next
                    index+=1
                nextNode = tempnode.next
                tempnode.next = newNode
                newNode.next = nextNode
            return f"{val} inserted at {location}"   
                
cll = CircularLL()
print(cll.createCLL(2))
cll.insertCLL(3,0)
cll.insertCLL(5,-1)
print(cll.insertCLL(2,1))
print(cll.insertCLL(10,7))
print([node.data for node in cll])
# Out:
# The CLL has been created
# 2 inserted at 1
# 10 inserted at 7
# [3, 2, 2, 10, 5]

# %% [markdown]
# ## Traversel

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class CircularLL:
    def __init__(self):
        self.head=None
        self.tail=None
        
    def __iter__(self):
        node= self.head
        while node:
            yield node
            node= node.next
            
            if node==self.tail.next:
                break
                
        
    def createCLL(self,val):
        node = Node(val)
        node.next = node
        self.head=node
        self.tail=node
        return "The CLL has been created"
    
    def insertCLL(self,val,location):
        if self.head==None:
            return "Node not found"
        else:
            newNode = Node(val)
            if location==0:
                newNode.next = self.head
                self.head = newNode
                self.tail.next = newNode
                
                
                
            elif location==-1:
                newNode.next=self.tail.next
                self.tail.next = newNode
                self.tail=newNode  
            
            else:
                tempnode= self.head
                index=0
                while index<location-1:
                    tempnode= tempnode.next
                    index+=1
                nextNode = tempnode.next
                tempnode.next = newNode
                newNode.next = nextNode
            return f"{val} inserted at {location}"   
        
    def traversel(self):
        if self.head ==None:
            print("There's no element.") 
        else:
            tempNode= self.head
            while tempNode:
                print(tempNode.data,"->",end="")
                tempNode = tempNode.next
                
                if tempNode == self.tail.next:
                    break
                
                
cll = CircularLL()
print(cll.createCLL(2))
cll.insertCLL(3,0)
cll.insertCLL(5,-1)
print(cll.insertCLL(2,1))
print(cll.insertCLL(10,7))
cll.traversel()
print()
print([node.data for node in cll])
# Out:
# The CLL has been created
# 2 inserted at 1
# 10 inserted at 7
# 3 ->2 ->2 ->10 ->5 ->
# [3, 2, 2, 10, 5]

# %% [markdown]
# ## Searching

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class CircularLL:
    def __init__(self):
        self.head=None
        self.tail=None
        
    def __iter__(self):
        node= self.head
        while node:
            yield node
            node= node.next
            
            if node==self.tail.next:
                break
                
        
    def createCLL(self,val):
        node = Node(val)
        node.next = node
        self.head=node
        self.tail=node
        return "The CLL has been created"
    
    def insertCLL(self,val,location):
        if self.head==None:
            return "Node not found"
        else:
            newNode = Node(val)
            if location==0:
                newNode.next = self.head
                self.head = newNode
                self.tail.next = newNode
                
                
                
            elif location==-1:
                newNode.next=self.tail.next
                self.tail.next = newNode
                self.tail=newNode  
            
            else:
                tempnode= self.head
                index=0
                while index<location-1:
                    tempnode= tempnode.next
                    index+=1
                nextNode = tempnode.next
                tempnode.next = newNode
                newNode.next = nextNode
            return f"{val} inserted at {location}"  
    
    def searchCLL(self,val):
        if self.head is None:
            return "There's no node"
        
        else:
            tempNode = self.head
            
            while tempNode:
                if tempNode.data == val:
                    return tempNode.data
                tempNode=tempNode.next
                if tempNode==self.tail.next:
                    return "The node doesn't exist"
    
    
            
                    
                
        
                    
                
cll = CircularLL()
print(cll.createCLL(2))
cll.insertCLL(3,0)
cll.insertCLL(5,-1)
print(cll.insertCLL(2,1))
print(cll.insertCLL(10,7))
print(cll.searchCLL(11))
print([node.data for node in cll])
# Out:
# The CLL has been created
# 2 inserted at 1
# 10 inserted at 7
# The node doesn't exist
# [3, 2, 2, 10, 5]
