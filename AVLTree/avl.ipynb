# %%
from queue import Queue
class AVLNode:
    def __init__(self, data):
        self.data = data
        self.leftchild= None
        self.rightchild = None
        height=1
        
def preordertraversal(rootNode):
    if not rootNode:
        return 
    print(rootNode.data)
    preordertraversal(rootNode.leftchild)
    preordertraversal(rootNode.rightchild)
    
def inOrderTraversel(rootNode):
    if not rootNode:
        return
    inOrderTraversel(rootNode.leftchild)
    print(rootNode.data)
    inOrderTraversel(rootNode.rightchild)
    
def postOrderTrversel(rootNode):
    if not rootNode:
        return 
    postOrderTrversel(rootNode.leftchild)
    postOrderTrversel(rootNode.rightchild)
    print(rootNode.data)
    
def levelOrderTraversel(rootNode):
    if rootNode==None:
        return 
    q=Queue()
    q.put(rootNode)

    while not q.empty():
        currnode = q.get()
        print(currnode.data)
        
        if currnode.leftchild is not None:
            q.put(currnode.leftchild)
    
        if currnode.rightchild is not None:
            q.put(currnode.rightchild)

def searchNode(rootNode,nodeval):
    if rootNode.data==nodeval:
        print("The value is found")
    elif nodeval < rootNode.data:
        if rootNode.leftchild.data == nodeval:
            print("The value is found")
        else:
            searchNode(rootNode.leftchild,nodeval)
    else:
        if rootNode.rightchild.data == nodeval:
            print("The value is found")
        else:
            searchNode(rootNode.rightchild,nodeval)
            
def getheight(rootNode):  
    if not rootNode:
        return 0
    return rootNode.height

def rightRotate(disbalnceNode):
    newroot = disbalnceNode.leftchild
    disbalnceNode.leftchild = disbalnceNode.leftchild.rightchild
    newroot.rightchild = disbalnceNode
    
    disbalnceNode.height = 1+ max(getheight(disbalnceNode.leftchild),getheight(disbalnceNode.rightchild))
    
    

    
    
        
    

    
    
newAVL = AVLNode(10)
levelOrderTraversel(newAVL)
searchNode(newAVL,10)
# Out:
# 10
# The value is found
